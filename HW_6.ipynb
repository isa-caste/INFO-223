# %%
# Question 1
numbers = []
while True:
    num_input = input("Enter a number (or 'done' to finish): ")
    if num_input.lower() == "done":
        break
    try:
        number = float(num_input)
        numbers.append(number)
    except ValueError:
        print("Invalid input. Please enter a number or 'done'.")
if numbers:
    maximum = max(numbers)
    minimum = min(numbers)
    print("Maximum:", maximum)
    print("Minimum:", minimum)
else:
    print("No numbers were entered.")
# Out:
# Enter a number (or 'done' to finish): 5
# Enter a number (or 'done' to finish): doen
# Invalid input. Please enter a number or 'done'.
# Enter a number (or 'done' to finish): done
# Maximum: 5.0
# Minimum: 5.0

# %%
# Question 2
str = 'X-DSPAM-Confidence: 0.8475'
colon_index = str.find(':') 
extracted_str = str[colon_index + 2:] 
float_number = float(extracted_str)  
print(float_number)
# Out:
# 0.8475

# %%
# Question 3 #1
string = "supercalifragilisticexpialidocious"
length = len(string)
print(length)
# Out:
# 34

# %%
# Question 3 #2
string = "supercalifragilisticexpialidocious"
first_substring = string[:5]
last_substring = string[-5:]
print(first_substring)
print(last_substring)
# Out:
# super
# cious

# %%
# Question 3 #3
string = "supercalifragilisticexpialidocious"
count_i = string.count("i")
print(count_i)
# Out:
# 7

# %%
# Question 4
string = "Alex, EyeColor:Black, HairColor:black, Major: Math, School:SoIC"
tokens = string.split(', ')
for token in tokens:
    print(token)
# Out:
# Alex
# EyeColor:Black
# HairColor:black
# Major: Math
# School:SoIC

# %%
# Question 5 #1
def chop(lst):
    if len(lst) >= 2:
        del lst[0]  
        del lst[-1]  
def middle(lst):
    if len(lst) >= 2:
        return lst[1:-1] 
    else:
        return []
print(chop)
# Out:
# <function chop at 0x000001C8C81DC670>
